# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import re

old_hdd_ori = pd.read_csv("../data/old_HDD.csv")

old_hdd = old_hdd_ori.copy()

old_hdd.head(5)
# Out:
#   first_name last_name                  title  release_year  category_id
# 0   PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1   PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2   PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3   PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4   PENELOPE   GUINESS          CHEAPER CLYDE          2006           14

# %%
#vamos a pasar todo a minúscula para unificar
old_hdd["first_name"] = old_hdd["first_name"].str.lower()
old_hdd["title"] = old_hdd["title"].str.lower()
old_hdd["last_name"] = old_hdd["last_name"].str.lower()

# %%
old_hdd.head(5)
# Out:
#   first_name last_name                  title  release_year  category_id
# 0   penelope   guiness       academy dinosaur          2006            6
# 1   penelope   guiness   anaconda confessions          2006            2
# 2   penelope   guiness            angels life          2006           13
# 3   penelope   guiness  bulworth commandments          2006           10
# 4   penelope   guiness          cheaper clyde          2006           14

# %%
#una vez unificado, vamos a comparar que valores que sean coincidentes con el archivo de films que tenemos

film_ori = pd.read_csv("../data/filmclean.csv")

film = film_ori.copy()

film.head(5)
# Out:
#    film_id             title  \
# 0        1  academy dinosaur
# 1        2    ace goldfinger
# 2        3  adaptation holes
# 3        4  affair prejudice
# 4        5       african egg
#
#                                          description  release_year  \
# 0  a epic drama of a feminist and a mad scientist...          2006
# 1  a astounding epistle of a database administrat...          2006
# 2  a astounding reflection of a lumberjack and a ...          2006
# 3  a fanciful documentary of a frisbee and a lumb...          2006
# 4  a fast-paced documentary of a pastry chef and ...          2006
#
#    rental_duration  rental_rate  length  replacement_cost rating  \
# 0                6         0.99      86             20.99     PG
# 1                3         4.99      48             12.99      G
# 2                7         2.99      50             18.99  NC-17
# 3                5         2.99     117             26.99      G
# 4                6         2.99     130             22.99      G
#
#                    special_features language
# 0  deleted scenes,behind the scenes  english
# 1           trailers,deleted scenes  english
# 2           trailers,deleted scenes  english
# 3    commentaries,behind the scenes  english
# 4                    deleted scenes  english

# %%
def coindicentes(titufilm, tituold):
    coincidentes = 0
    for i in titufilm:
        for e in tituold:
            if e == i:
                coincidentes += 1
    return(coincidentes)

coindicentes(old_hdd["title"],film.title )
# Out:
# 1000
